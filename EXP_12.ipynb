# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshmisrinivasulureddy/Digital-Forensics/blob/main/EXP_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pillow

from PIL import Image
from PIL.ExifTags import TAGS
image = Image.new("RGB", (300, 300), color="blue")
image.save("sample.jpg")
img = Image.open("sample.jpg")
exif = img.getexif()

print("Image Name :", "sample.jpg")
print()

if len(exif) == 0:
    print("No EXIF metadata found in the image.")
else:
    print("EXIF Metadata:\n")
    for tag_id, value in exif.items():
        tag = TAGS.get(tag_id, tag_id)
        print(f"{tag} : {value}")
# Out:
# ...
# Image Name : sample.jpg
#
# No EXIF metadata found in the image.
