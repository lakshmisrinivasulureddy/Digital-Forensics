# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshmisrinivasulureddy/Digital-Forensics/blob/main/EXP_28.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re

passwords = [
    "123456",
    "admin",
    "password",
    "Welcome123",
    "Strong@123"
]

print("Weak Password Detection\n")

for pwd in passwords:
    if len(pwd) < 8 or pwd.isalpha() or pwd.isdigit():
        print(pwd, "-> Weak")
    else:
        print(pwd, "-> Strong")

print("\nSQL Injection Detection")

payloads = [
    "' OR 1=1 --",
    "admin",
    "UNION SELECT *",
    "../etc/passwd",
    "normal search"
]

for p in payloads:

    if re.search(r"or\s+1=1|union|--", p, re.I):
        print(p, "-> SQL Injection")

    elif "../" in p:
        print(p, "-> Directory Traversal")

    else:
        print(p, "-> Normal Request")
# Out:
# Weak Password Detection
#
# 123456 -> Weak
# admin -> Weak
# password -> Weak
# Welcome123 -> Strong
# Strong@123 -> Strong
#
# SQL Injection Detection
# ' OR 1=1 -- -> SQL Injection
# admin -> Normal Request
# UNION SELECT * -> SQL Injection
# ../etc/passwd -> Directory Traversal
# normal search -> Normal Request
