# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshmisrinivasulureddy/Digital-Forensics/blob/main/EXP_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import defaultdict

records = int(input("Enter number of network records: "))

ports = defaultdict(set)

for i in range(records):
    print("\nRecord", i + 1)

    ip = input("Source IP: ")
    port = int(input("Destination Port: "))

    ports[ip].add(port)

print("\nScanning Report")
print("----------------------")

found = False

for ip in ports:
    if len(ports[ip]) >= 5:
        print(ip, "is a Possible Port Scanner.")
        print("Ports Accessed:", sorted(ports[ip]))
        found = True

if not found:
    print("No port scanning behaviour detected.")
# Out:
# Enter number of network records: 2
#
# Record 1
# Source IP: 192.168.1.15
# Destination Port: 23
#
# Record 2
# Source IP: 192.168.1.14
# Destination Port: 21
#
# Scanning Report
# ----------------------
# No port scanning behaviour detected.
