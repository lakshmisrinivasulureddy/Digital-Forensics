# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshmisrinivasulureddy/Digital-Forensics/blob/main/EXP_15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import psutil

# Create evidence directory
evidence_dir = "digital_evidence"
os.makedirs(evidence_dir, exist_ok=True)

# Create sample evidence files
sample_evidence = {
    "email_log.txt": """From: attacker@mail.com
To: victim@mail.com
Subject: Invoice

Please pay immediately.""",

    "browser_history.txt": """http://malicious-site.com/login
http://bank.com/transfer""",

    "chat_message.txt": "Hey, did you send the file?",

    "system_log.txt": "2026-07-24 10:15:32 - USB device connected: E:\\"
}

for filename, content in sample_evidence.items():
    with open(os.path.join(evidence_dir, filename), "w") as f:
        f.write(content)


# Capture volatile evidence
def capture_volatile_evidence():
    processes = [p.info for p in psutil.process_iter(['pid', 'name'])]
    return {
        "running_process_count": len(processes),
        "sample_processes": processes[:5]
    }


# Capture non-volatile evidence
def capture_nonvolatile_evidence(folder):
    files = sorted(os.listdir(folder))
    return {
        "disk_files": files,
        "file_count": len(files)
    }


# Collect evidence
volatile_snapshot = capture_volatile_evidence()
nonvolatile_snapshot = capture_nonvolatile_evidence(evidence_dir)


# Display results
print("===== VOLATILE EVIDENCE =====")
print("Running processes:", volatile_snapshot["running_process_count"])

print("\nSample running processes:")
for process in volatile_snapshot["sample_processes"]:
    print(process)

print("\n===== NON-VOLATILE EVIDENCE =====")
print("Files found:")
for file in nonvolatile_snapshot["disk_files"]:
    print("-", file)

print("\nTotal files:", nonvolatile_snapshot["file_count"])
# Out:
# ===== VOLATILE EVIDENCE =====
# Running processes: 15
#
# Sample running processes:
# {'name': 'docker-init', 'pid': 1}
# {'name': 'node', 'pid': 7}
# {'name': 'oom_monitor.sh', 'pid': 21}
# {'name': 'run.sh', 'pid': 23}
# {'name': 'kernel_manager_proxy', 'pid': 24}
#
# ===== NON-VOLATILE EVIDENCE =====
# Files found:
# - browser_history.txt
# - chat_message.txt
# - email_log.txt
# - system_log.txt
#
# Total files: 4
