# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshmisrinivasulureddy/Digital-Forensics/blob/main/EXP_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sender = input("Enter sender email: ")
subject = input("Enter subject: ")
body = input("Enter email body: ")

score = 0


if "unknown" in sender.lower() or "@fake" in sender.lower():
    score += 1

if "urgent" in subject.lower() or "verify" in subject.lower():
    score += 1

if "click here" in body.lower() or "password" in body.lower():
    score += 1

if score >= 2:
    print("\nPhishing Email Detected!")
else:
    print("\nEmail appears Safe.")
# Out:
# Enter sender email: unknown@fake.com
# Enter subject:  Urgent Account Verification
# Enter email body:   Click here to verify your password
#
# Phishing Email Detected!
