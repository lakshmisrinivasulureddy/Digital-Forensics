# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshmisrinivasulureddy/Digital-Forensics/blob/main/EXP_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import hashlib


with open("evidence.txt", "w") as f:
    f.write("Digital Evidence")

with open("evidence.txt", "rb") as f:
    file_hash = hashlib.sha256(f.read()).hexdigest()

print("SHA-256 Hash:")
print(file_hash)

print("\nChain of Custody Verified: File Integrity Maintained")
# Out:
# SHA-256 Hash:
# 1b84760df2942278d3062469489473ad33bb037bf12056ffcee9e5c3d9841894
#
# Chain of Custody Verified: File Integrity Maintained
