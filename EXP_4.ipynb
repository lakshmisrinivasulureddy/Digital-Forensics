# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshmisrinivasulureddy/Digital-Forensics/blob/main/EXP_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import socket

domain = input("Enter domain name: ")

try:
    ip = socket.gethostbyname(domain)
    print("\nDNS Lookup Result")
    print("Domain :", domain)
    print("IP Address :", ip)
except socket.gaierror:
    print("Invalid domain or DNS lookup failed.")
# Out:
# Enter domain name: google.com
#
# DNS Lookup Result
# Domain : google.com
# IP Address : 172.253.117.102
